# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('E:\Technolabs\datasets\yearly_deaths_by_clinic.csv')

# %%
df
# Out:
#     year  births  deaths    clinic
# 0   1841    3036     237  clinic 1
# 1   1842    3287     518  clinic 1
# 2   1843    3060     274  clinic 1
# 3   1844    3157     260  clinic 1
# 4   1845    3492     241  clinic 1
# 5   1846    4010     459  clinic 1
# 6   1841    2442      86  clinic 2
# 7   1842    2659     202  clinic 2
# 8   1843    2739     164  clinic 2
# 9   1844    2956      68  clinic 2
# 10  1845    3241      66  clinic 2
# 11  1846    3754     105  clinic 2

# %%
df.describe()
# Out:
#               year       births      deaths
# count    12.000000    12.000000   12.000000
# mean   1843.500000  3152.750000  223.333333
# std       1.783765   449.078476  145.383089
# min    1841.000000  2442.000000   66.000000
# 25%    1842.000000  2901.750000  100.250000
# 50%    1843.500000  3108.500000  219.500000
# 75%    1845.000000  3338.250000  263.500000
# max    1846.000000  4010.000000  518.000000

# %%
rcParams['figure.figsize'] = 10,6
plt.plot(df.year)
plt.plot(df.deaths)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# # Task 1:

# %%
df["proportion_deaths"]=df['deaths']/df['births']

# %%
df
# Out:
#     year  births  deaths    clinic  proportion_deaths
# 0   1841    3036     237  clinic 1           0.078063
# 1   1842    3287     518  clinic 1           0.157591
# 2   1843    3060     274  clinic 1           0.089542
# 3   1844    3157     260  clinic 1           0.082357
# 4   1845    3492     241  clinic 1           0.069015
# 5   1846    4010     459  clinic 1           0.114464
# 6   1841    2442      86  clinic 2           0.035217
# 7   1842    2659     202  clinic 2           0.075968
# 8   1843    2739     164  clinic 2           0.059876
# 9   1844    2956      68  clinic 2           0.023004
# 10  1845    3241      66  clinic 2           0.020364
# 11  1846    3754     105  clinic 2           0.027970

# %% [markdown]
# # Task 2:

# %%
yearly1 = df[df['clinic']=='clinic 1']

# %%
yearly1
# Out:
#    year  births  deaths    clinic  proportion_deaths
# 0  1841    3036     237  clinic 1           0.078063
# 1  1842    3287     518  clinic 1           0.157591
# 2  1843    3060     274  clinic 1           0.089542
# 3  1844    3157     260  clinic 1           0.082357
# 4  1845    3492     241  clinic 1           0.069015
# 5  1846    4010     459  clinic 1           0.114464

# %%
yearly2 = df[df['clinic']=='clinic 2']
yearly2
# Out:
#     year  births  deaths    clinic  proportion_deaths
# 6   1841    2442      86  clinic 2           0.035217
# 7   1842    2659     202  clinic 2           0.075968
# 8   1843    2739     164  clinic 2           0.059876
# 9   1844    2956      68  clinic 2           0.023004
# 10  1845    3241      66  clinic 2           0.020364
# 11  1846    3754     105  clinic 2           0.027970

# %% [markdown]
# # Task 3:

# %%
ax = yearly1.plot(x="year",y="proportion_deaths",label="clinic 1")

# %%
ex = yearly2.plot(x="year",y="proportion_deaths",label="clinic 2")

# %%
yearly2.plot(x="year",y="proportion_deaths",label="clinic 2",ax=ax)

# %% [markdown]
# # Task 4:

# %%
monthly = pd.read_csv("E:\Technolabs\datasets\monthly_deaths.csv",parse_dates=["date"])
monthly
# Out:
#          date  births  deaths
# 0  1841-01-01     254      37
# 1  1841-02-01     239      18
# 2  1841-03-01     277      12
# 3  1841-04-01     255       4
# 4  1841-05-01     255       2
# ..        ...     ...     ...
# 93 1848-11-01     310       9
# 94 1848-12-01     373       5
# 95 1849-01-01     403       9
# 96 1849-02-01     389      12
# 97 1849-03-01     406      20
#
# [98 rows x 3 columns]

# %%
monthly.dtypes
# Out:
# date      datetime64[ns]
# births             int64
# deaths             int64
# dtype: object

# %%
monthly.describe()
# Out:
#            births     deaths
# count   98.000000  98.000000
# mean   267.000000  22.469388
# std     41.769372  18.141031
# min    190.000000   0.000000
# 25%    242.500000   8.000000
# 50%    264.000000  16.500000
# 75%    292.750000  36.750000
# max    406.000000  75.000000

# %%
monthly["proportion_deaths"] = monthly['deaths']/monthly['births']
monthly.head()
# Out:
#         date  births  deaths  proportion_deaths
# 0 1841-01-01     254      37           0.145669
# 1 1841-02-01     239      18           0.075314
# 2 1841-03-01     277      12           0.043321
# 3 1841-04-01     255       4           0.015686
# 4 1841-05-01     255       2           0.007843

# %% [markdown]
# # Task 5

# %%
sns.lineplot(x="date",y="proportion_deaths",hue=yearly1.clinic,data=monthly)

# %%
sns.lineplot(x="date",y="proportion_deaths",hue=yearly2.clinic,data=monthly)

# %%
ax = monthly.plot(x='date',y="proportion_deaths")

# %%
ax.set_ylabel("proportion_deaths")
# Out:
# Text(3.200000000000003, 0.5, 'proportion_deaths')

# %% [markdown]
# # Task 6

# %%
pd.to_datetime(monthly['date'])
# Out:
# 0    1841-01-01
# 1    1841-02-01
# 2    1841-03-01
# 3    1841-04-01
# 4    1841-05-01
#         ...
# 93   1848-11-01
# 94   1848-12-01
# 95   1849-01-01
# 96   1849-02-01
# 97   1849-03-01
# Name: date, Length: 98, dtype: datetime64[ns]

# %%
handwashing_start = pd.to_datetime('1847-01-01')
handwashing_start
# Out:
# Timestamp('1847-01-01 00:00:00')

# %%
hand_wash = monthly[monthly['date']== handwashing_start]
hand_wash
# Out:
#          date  births  deaths  proportion_deaths
# 71 1847-01-01     311      10           0.032154

# %% [markdown]
# ### Handwashing Discovered on 1847, Splitting data as

# %%
before_washing = monthly[monthly['date'] < handwashing_start]
before_washing
# Out:
#          date  births  deaths  proportion_deaths
# 0  1841-01-01     254      37           0.145669
# 1  1841-02-01     239      18           0.075314
# 2  1841-03-01     277      12           0.043321
# 3  1841-04-01     255       4           0.015686
# 4  1841-05-01     255       2           0.007843
# ..        ...     ...     ...                ...
# 66 1846-08-01     216      39           0.180556
# 67 1846-09-01     271      39           0.143911
# 68 1846-10-01     254      38           0.149606
# 69 1846-11-01     297      32           0.107744
# 70 1846-12-01     298      16           0.053691
#
# [71 rows x 4 columns]

# %%
after_washing = monthly[monthly['date'] >= handwashing_start]
after_washing
# Out:
#          date  births  deaths  proportion_deaths
# 71 1847-01-01     311      10           0.032154
# 72 1847-02-01     312       6           0.019231
# 73 1847-03-01     305      11           0.036066
# 74 1847-04-01     312      57           0.182692
# 75 1847-05-01     294      36           0.122449
# 76 1847-06-01     268       6           0.022388
# 77 1847-07-01     250       3           0.012000
# 78 1847-08-01     264       5           0.018939
# 79 1847-09-01     262      12           0.045802
# 80 1847-10-01     278      11           0.039568
# 81 1847-11-01     246      11           0.044715
# 82 1847-12-01     273       8           0.029304
# 83 1848-01-01     283      10           0.035336
# 84 1848-02-01     291       2           0.006873
# 85 1848-03-01     276       0           0.000000
# 86 1848-04-01     305       2           0.006557
# 87 1848-05-01     313       3           0.009585
# 88 1848-06-01     264       3           0.011364
# ...

# %%
sns.lineplot(x="date",y="proportion_deaths",data=before_washing)

# %%
ax = before_washing.plot(x='date',y='proportion_deaths',label='before_washing')

# %%
sns.lineplot(x="date",y="proportion_deaths",label ='after_washing',data=after_washing)

# %%
after_washing.plot(x='date',y='proportion_deaths', label ='after_washing',ax=ax)

# %% [markdown]
# ## Task 7

# %%
before_proportion = before_washing['proportion_deaths']
before_proportion
# Out:
# 0     0.145669
# 1     0.075314
# 2     0.043321
# 3     0.015686
# 4     0.007843
#         ...
# 66    0.180556
# 67    0.143911
# 68    0.149606
# 69    0.107744
# 70    0.053691
# Name: proportion_deaths, Length: 71, dtype: float64

# %%
after_proportion = after_washing['proportion_deaths']
after_proportion
# Out:
# 71    0.032154
# 72    0.019231
# 73    0.036066
# 74    0.182692
# 75    0.122449
# 76    0.022388
# 77    0.012000
# 78    0.018939
# 79    0.045802
# 80    0.039568
# 81    0.044715
# 82    0.029304
# 83    0.035336
# 84    0.006873
# 85    0.000000
# 86    0.006557
# 87    0.009585
# 88    0.011364
# 89    0.003717
# 90    0.000000
# 91    0.009615
# 92    0.023411
# 93    0.029032
# 94    0.013405
# 95    0.022333
# 96    0.030848
# 97    0.049261
# Name: proportion_deaths, dtype: float64

# %%
diff_mean = after_proportion.mean()-before_proportion.mean()
diff_mean
# Out:
# -0.07519076642777145

# %% [markdown]
# # Task 8

# %%
#boot_col = before_proportion.sample(frac=1, replace=True)

# %%
boot_mean_diff=[]

# %%
for i in range(3000):
    boot_before = before_proportion.sample(frac=1, replace=True)
    boot_after = after_proportion.sample(frac=1,replace=True)
    boot_mean_diff.append(boot_after.mean()-boot_before.mean())

# %%
boot_mean_diff
# Out:
# [-0.07866751330989682,
#  -0.06370671410541695,
#  -0.07392046942864686,
#  -0.08450358927331705,
#  -0.07595883754147165,
#  -0.056001356785110784,
#  -0.07323146300129901,
#  -0.07076882026775179,
#  -0.07339650251385835,
#  -0.08165424507034505,
#  -0.08127834792029384,
#  -0.08433429730416211,
#  -0.08535947909442103,
#  -0.07197777085456258,
#  -0.07979730941356294,
#  -0.06669276093928328,
#  -0.09120414988274118,
#  -0.06755989777830013,
#  -0.07790378296160105,
#  -0.07678165722752144,
#  -0.06415444977996926,
#  -0.08264524237639617,
#  -0.06732553192877044,
#  -0.0886286253925482,
#  -0.09373310590517116,
#  -0.0721041206874917,
#  -0.07995887620378442,
#  -0.05827471962993535,
#  -0.07865342229050853,
#  -0.07647434028214925,
#  -0.06774872088332251,
#  -0.08376758510362715,
#  -0.0702185494038958,
#  -0.09144243669864158,
#  -0.07040410192223995,
#  -0.08235732447907662,
#  -0.060800873902736884,
#  -0.08067446731398839,
#  -0.07888628331363974,
#  -0.06968120892961915,
# ...

# %% [markdown]
# ### Calculating 95% confidence interval as 2.5%, 97.5% quantiles

# %%
pd.Series(boot_mean_diff).quantile([0.025, 0.975])
# Out:
# 0.025   -0.096678
# 0.975   -0.052522
# dtype: float64

# %% [markdown]
# # Task 9
